# %% [markdown]
# ## Kata modulo 2

# %% [markdown]
# ### se acedio a la carpeta para que de esta manera se pudiera actviar el comando

# %%
from IPython.display import Image
Image(filename='venv_env.png')

# %% [markdown]
# ## Intalación de Deteutil

# %% [markdown]
# Se instalo la libreria de Deteutil en el entorno virtual

# %%
from IPython.display import Image
Image(filename='install_deteutil.png')

# %% [markdown]
# ## Instalación de la libreria pip

# %%
from IPython.display import Image
Image(filename='pip.png')
